# %%
import pandas as pd
import random

# %%
df=pd.read_csv('Final_test_data.csv')

# %%
df
# Out:
#             DATE  PRODUCT_ID  SELLING_PRICE  COST_PRICE  COMPETITOR_PRICE  \
# 0     2024-03-01           1     383.540818  197.989133        405.290680
# 1     2024-03-01           2      43.502901   30.552955         40.457301
# 2     2024-03-01           3      49.381390   22.282695         49.820216
# 3     2024-03-01           4     186.108696  157.102309        189.534233
# 4     2024-03-01           5     459.921642  295.345194        436.443848
# ...          ...         ...            ...         ...               ...
# 3095  2024-03-31          96     216.330694  128.139932        203.075904
# 3096  2024-03-31          97     200.992760  136.927526        219.748747
# 3097  2024-03-31          98     188.888741  138.307450        195.910036
# 3098  2024-03-31          99     278.653458  204.865767        274.796798
# 3099  2024-03-31         100      85.739741   59.085228         80.771645
#
#              SALES  IS_PROMOTION  QUANTITY   CATEGORY    SUBCATEGORY  ...  \
# ...

# %%
def adjust_projected_sales(row):
   if row['Projected Selling Price'] > row['SELLING_PRICE']:
       row['Projected Sales'] = row['SALES'] * random.uniform(0.7,0.95)
   elif row['Projected Selling Price'] < row['SELLING_PRICE']:
       increase_factor = random.uniform(1.1,1.5)
       row['Projected Sales'] = row['SALES'] * increase_factor
   return row
df = df.apply(adjust_projected_sales, axis=1)

print(df[['DATE', 'PRODUCT_ID', 'SELLING_PRICE', 'Projected Selling Price', 'SALES', 'Projected Sales']].head())
# Out:
#          DATE  PRODUCT_ID  SELLING_PRICE  Projected Selling Price  \
# 0  2024-03-01           1     383.540818               387.573413
# 1  2024-03-01           2      43.502901                45.900080
# 2  2024-03-01           3      49.381390                47.622911
# 3  2024-03-01           4     186.108696               183.604084
# 4  2024-03-01           5     459.921642               461.296412
#
#           SALES  Projected Sales
# 0  133472.20470    100899.658534
# 1  105451.03200     88346.670056
# 2   64442.71391     90178.294287
# 3  388594.95760    470072.378483
# 4  860053.47120    710187.357318

# %%
df.to_csv('Final_Projected_Data.csv')
